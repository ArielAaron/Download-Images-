# %% [markdown]
# # EXTRAYENDO IMAGENES DE UNA URL
# ## PAQUETES UTILIZADOS
# ### 1. request
# Es una librería que nos proporciona una interfaz fácil de utilizar con http, lo que simplifica el proceso de envió y recepción
# de datos de las páginas web
# ### 2. bs4
# Es una librería que nos permite el web scrapping, es decir extraer información de las páginas web.
# ### 3. pandas
# Es una librería de software de código abierto que se utiliza para analizar y manipular datos en Python
# ### 4. urllib.request
# Es una librería que nos proporciona una manera simple de obtener URL usando una variedad de protocolos
# ### 5. os
# Es una librería que nos permite interacturar con los programas del sisteme operativo

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
pd.set_option('display.max_colwidth',None)
import urllib.request
import os

# %%
#Extrayendo URL link
Contenido=requests.get("https://science.nasa.gov/mission/hubble/science/explore-the-night-sky/hubble-messier-catalog/?exclude_child_pages=false&order=ASC&orderby=menu_order&layout=grid&number_of_items=100&requesting_id=29926&science_only=false&show_content_type_tags=no&show_excerpts=yes&show_pagination=false&show_readtime=no&show_thumbnails=yes&response_format=html&listing_page=no&listing_page_category_id=1170&post_types=mission&categories=3608").text
soup=BeautifulSoup(Contenido,'html.parser')
imagenes=soup.find_all('img')

# %% [markdown]
# ## PRIMERA FORMA
# - Se extrae la URL, para lo cual se crea una variable datos, podemos hacerlo mediante dos formas

# %%
datos=[]
for image in imagenes:
    image_src=(image.get('src'))
    datos.append(image_src)

# %% [markdown]
# ## SEGUNDA FORMA

# %%
imagenes_src=[image.get('src') for image in imagenes]
images_M=list(imagenes_src)

# %% [markdown]
# ## CREACION DE UN DATAFRAME CON PANDAS

# %%
images_df=pd.DataFrame(datos)
images_df=images_df.rename({0:"URL"},axis='columns')     #Renombrar el encabezado
images_df.head(10)                                       #Muestra
# Out:
#                                                                                                                  URL
# 0                               https://science.nasa.gov/wp-content/themes/nasa-child/assets/images/nasa-logo@2x.png
# 1                               https://science.nasa.gov/wp-content/themes/nasa-child/assets/images/nasa-logo@2x.png
# 2                                                    https://www.nasa.gov/wp-content/uploads/2025/01/med-mounted.jpg
# 3                            https://science.nasa.gov/wp-content/uploads/2024/01/hubble-ngc1356-potw2352a.jpg?w=1024
# 4                                               https://www.nasa.gov/wp-content/uploads/2025/01/jsc2024e063102-1.jpg
# 5                                                    https://www.nasa.gov/wp-content/uploads/2025/01/med-mounted.jpg
# 6                            https://science.nasa.gov/wp-content/uploads/2024/01/hubble-ngc1356-potw2352a.jpg?w=1024
# 7                                               https://www.nasa.gov/wp-content/uploads/2025/01/jsc2024e063102-1.jpg
# 8                                        https://www.nasa.gov/wp-content/uploads/2025/01/jsc2023e030777-bluejet.webp
# 9  https://www.nasa.gov/wp-content/uploads/2022/04/apollo_16_landing_37_eva3_lm_w_rover_and_young_as16-116-18578.jpg

# %% [markdown]
# ### La URL de las imagenes que deseamos extraer tiene las siguientes características
# - 1) https:
# - 2) science.nasa.gov
# - 3) wp-content
# - 4) uploads
# - 5) year
# - 6) month
# - 7) name_img
#
# ### Diviendo el URL en columnas para hallar las relaciones

# %%
images_df[['P1','P2','P3','P4','P5','P6','P7','P8','P9','P10','P11','P12']]=images_df['URL'].str.split('/',n=11,expand=True)
images_df.describe()
# Out:
#                                                                     URL  \
# count                                                               131
# unique                                                              114
# top     https://www.nasa.gov/wp-content/uploads/2025/01/med-mounted.jpg
# freq                                                                  4
#
#             P1   P2                P3          P4       P5    P6   P7  \
# count      131  131               131         131      131   131  130
# unique       1    1                 4           4        5     9   14
# top     https:       science.nasa.gov  wp-content  uploads  2023   04
# freq       131  131                98         119      116    85   83
#
#                      P8                P9   P10  \
# count               130                14     9
# unique              111                 7     6
# top     med-mounted.jpg  nasa-logo@2x.png  4110
# freq                  4                 3     3
#
#                                                                                        P11  \
# count                                                                                    9
# unique                                                                                   6
# top     Glowing_bands_over_Earth_at_night.gif?w=800&h=600&fit=clip&crop=faces%2Cfocalpoint
# freq                                                                                     3
#
#                                                                             P12
# count                                                                         3
# unique                                                                        2
# top     fig-cover-na-v3-wide.png?w=6809&h=3827&fit=clip&crop=faces%2Cfocalpoint
# freq                                                                          2

# %%
P3_count=images_df.P3.value_counts()
P4_count=images_df.P4.value_counts()
P5_count=images_df.P5.value_counts()
print(P3_count)
print(P4_count)
print(P5_count)
# Out:
# science.nasa.gov           98
# www.nasa.gov               21
# assets.science.nasa.gov    11
# images-assets.nasa.gov      1
# Name: P3, dtype: int64
# wp-content      119
# dynamicimage      8
# content           3
# image             1
# Name: P4, dtype: int64
# uploads          116
# assets             8
# themes             3
# dam                3
# iss072e034702      1
# Name: P5, dtype: int64

# %% [markdown]
# #### Actualizamos nuestro dataframe con los siguientes filtros
# 1. Filtramos con 'science.nasa.gov'
# 2. Eliminamos las primeras 9 que no tienen relacion
# 3. Eliminamos la última que es el logo

# %%
df=images_df[images_df['P3'] == 'science.nasa.gov']  
df=df.drop(df.index[0:10]) 
df=df.drop([df.index[87]])
df
# Out:
#                                                                                                            URL  \
# 43                      https://science.nasa.gov/wp-content/uploads/2023/04/crab-nebula-mosaic-jpg.webp?w=1024
# 44                                      https://science.nasa.gov/wp-content/uploads/2023/04/m2-jpg.webp?w=1024
# 45                                      https://science.nasa.gov/wp-content/uploads/2023/04/m3-jpg.webp?w=1024
# 46                               https://science.nasa.gov/wp-content/uploads/2023/04/potw1236a-jpg.webp?w=1024
# 47                               https://science.nasa.gov/wp-content/uploads/2023/04/potw1118a-jpg.webp?w=1024
# ..                                                                                                         ...
# 125                                 https://science.nasa.gov/wp-content/uploads/2023/04/m106-1-jpg.webp?w=1024
# 126                              https://science.nasa.gov/wp-content/uploads/2023/04/potw1229a-jpg.webp?w=1024
# 127  https://science.nasa.gov/wp-content/uploads/2018/03/hubble-m108-1-flat-final-new-tag-new-image.jpg?w=1024
# 128                 https://science.nasa.gov/wp-content/uploads/2023/06/hubble-m109-wfc3-2flat-jpg.webp?w=1024
# 129                                        https://science.nasa.gov/wp-content/uploads/2023/04/m110.png?w=1024
#
#          P1 P2                P3          P4       P5    P6  P7  \
# 43   https:     science.nasa.gov  wp-content  uploads  2023  04
# 44   https:     science.nasa.gov  wp-content  uploads  2023  04
# 45   https:     science.nasa.gov  wp-content  uploads  2023  04
# 46   https:     science.nasa.gov  wp-content  uploads  2023  04
# 47   https:     science.nasa.gov  wp-content  uploads  2023  04
# ..      ... ..               ...         ...      ...   ...  ..
# 125  https:     science.nasa.gov  wp-content  uploads  2023  04
# 126  https:     science.nasa.gov  wp-content  uploads  2023  04
# 127  https:     science.nasa.gov  wp-content  uploads  2018  03
# 128  https:     science.nasa.gov  wp-content  uploads  2023  06
# 129  https:     science.nasa.gov  wp-content  uploads  2023  04
#
#                                                         P8    P9   P10   P11  \
# 43                      crab-nebula-mosaic-jpg.webp?w=1024  None  None  None
# 44                                      m2-jpg.webp?w=1024  None  None  None
# 45                                      m3-jpg.webp?w=1024  None  None  None
# 46                               potw1236a-jpg.webp?w=1024  None  None  None
# 47                               potw1118a-jpg.webp?w=1024  None  None  None
# ..                                                     ...   ...   ...   ...
# 125                                 m106-1-jpg.webp?w=1024  None  None  None
# 126                              potw1229a-jpg.webp?w=1024  None  None  None
# 127  hubble-m108-1-flat-final-new-tag-new-image.jpg?w=1024  None  None  None
# 128                 hubble-m109-wfc3-2flat-jpg.webp?w=1024  None  None  None
# 129                                        m110.png?w=1024  None  None  None
#
#       P12
# 43   None
# 44   None
# 45   None
# 46   None
# 47   None
# ..    ...
# 125  None
# 126  None
# 127  None
# 128  None
# 129  None
#
# [87 rows x 13 columns]

# %% [markdown]
# #### Creamos los nombres de las imágenes

# %%
nameimg=df['P8'].str.split('.',expand=True)
nameimg.head(5)
# Out:
#                          0            1
# 41            opo0420b-jpg   webp?w=800
# 42     charles_messier-jpg   webp?w=621
# 43  crab-nebula-mosaic-jpg  webp?w=1024
# 44                  m2-jpg  webp?w=1024
# 45                  m3-jpg  webp?w=1024

# %%
#Definimos la función para descargar
def download_image(image_url, save_as):
    urllib.request.urlretrieve(image_url, save_as)

# %% [markdown]
# En status_code se utiliza el valor 200 para identificar que el servidor tiene acceso de manera existosa, en pocas palabras"Ok"
# ##### https://en.wikipedia.org/wiki/List_of_HTTP_status_codes

# %%
#Definimos la función para guardar en una carpeta especifica 
def download_imgdir(image_url, file_dir):
    response = requests.get(image_url)

    if response.status_code == 200:
        directory = os.path.dirname(file_dir)
        if not os.path.exists(directory):
            os.makedirs(directory)

        with open(file_dir, "wb") as fp:
            fp.write(response.content)
        print("Descarga exitosa")
    else:
        print(f"Fallo en descargar la imagen. Status code: {response.status_code}")

# %%
#Finalmente con el ciclo For empezamos a revisar cada URL y empezar a descargar cada una 
for i in range(len(df)):
    image_url=df['URL'].iloc[i]
    save_as=nameimg[0].iloc[i]+'.png'
    file_dir='C:/Users/Ariel/Desktop/Visual Data/Messier Img/' + save_as
    download_image(image_url,save_as)
    download_imgdir(image_url,file_dir)
    response = requests.get(image_url)
    print(image_url)
    print(response)
    print(save_as)
# Out:
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/crab-nebula-mosaic-jpg.webp?w=1024
# <Response [200]>
# opo0420b-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/m2-jpg.webp?w=1024
# <Response [200]>
# charles_messier-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/m3-jpg.webp?w=1024
# <Response [200]>
# crab-nebula-mosaic-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/potw1236a-jpg.webp?w=1024
# <Response [200]>
# m2-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/potw1118a-jpg.webp?w=1024
# <Response [200]>
# m3-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/06/hubble-m7-wfc3-2-flat-final-jpg.webp?w=987
# <Response [200]>
# potw1236a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/heic1015a-jpg.webp?w=1024
# <Response [200]>
# potw1118a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/heic1205a-jpg.webp?w=1024
# <Response [200]>
# hubble-m7-wfc3-2-flat-final-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/potw1225a-jpg.webp?w=1024
# <Response [200]>
# heic1015a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/m11-jpg.webp?w=1024
# <Response [200]>
# heic1205a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/potw1113a-jpg.webp?w=1024
# <Response [200]>
# potw1225a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/m13-xlarge_web-jpg.webp?w=1024
# <Response [200]>
# m11-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/hubble_m14_wfc3_1flat_cont_final-jpg.webp?w=1024
# <Response [200]>
# potw1113a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/heic1321a-jpg.webp?w=1024
# <Response [200]>
# m13-xlarge_web-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/hubble_birthofstars_0-jpg.webp?w=1024
# <Response [200]>
# hubble_m14_wfc3_1flat_cont_final-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2017/10/m17-field2-f110wf160w-a1-final-vers1-tag-new-image.jpg?w=1024
# <Response [200]>
# heic1321a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/hubble_m19_wfc3_str_gapfilled_flat_cont_final-jpg.webp?w=1024
# <Response [200]>
# hubble_birthofstars_0-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/trifid-neb-full_jpg-jpg.webp?w=1024
# <Response [200]>
# m17-field2-f110wf160w-a1-final-vers1-tag-new-image.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/potw1514a-jpg.webp?w=1024
# <Response [200]>
# hubble_m19_wfc3_str_gapfilled_flat_cont_final-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/opo0306a-jpg.webp?w=1024
# <Response [200]>
# trifid-neb-full_jpg-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/m28-jpg.webp?w=1024
# <Response [200]>
# potw1514a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/heic0918a-jpg.webp?w=1024
# <Response [200]>
# opo0306a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/hs-2015-02-a-hires_jpg-jpg.webp?w=1024
# <Response [200]>
# m28-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/m32_acs_field2_3b_flat_gapfill_final-jpg.webp?w=1024
# <Response [200]>
# heic0918a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/heic1901a-jpg.webp?w=1024
# <Response [200]>
# hs-2015-02-a-hires_jpg-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/orion-nebula-xlarge_web-jpg.webp?w=1024
# <Response [200]>
# m32_acs_field2_3b_flat_gapfill_final-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/heic0601c-jpg.webp?w=1024
# <Response [200]>
# heic1901a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2024/03/hubble-m44-acs-1-color-2-final-tag-new.jpg?w=1024
# <Response [200]>
# orion-nebula-xlarge_web-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/interstellar_cloud_in_pleiades-jpg.webp?w=1024
# <Response [200]>
# heic0601c-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/hubble_ngc2438_wfpc2_screen_3mb.png?w=1024
# <Response [200]>
# hubble-m44-acs-1-color-2-final-tag-new.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2024/08/hubble-m48-1-flat-final-new.jpg?w=1024
# <Response [200]>
# interstellar_cloud_in_pleiades-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/m49.png?w=1024
# <Response [200]>
# hubble_ngc2438_wfpc2_screen_3mb.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/m51-and-companion_0-jpg.webp?w=1024
# <Response [200]>
# hubble-m48-1-flat-final-new.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/potw1140a-jpg.webp?w=1024
# <Response [200]>
# m49.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/potw1145a-jpg.webp?w=1024
# <Response [200]>
# m51-and-companion_0-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/06/hubble-m55-mos-acs-long-flat-final2-jpg.webp?w=1024
# <Response [200]>
# potw1140a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/potw1234a-jpg.webp?w=1024
# <Response [200]>
# potw1145a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/ring-nebula-full_jpg-jpg.webp?w=1024
# <Response [200]>
# hubble-m55-mos-acs-long-flat-final2-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/m58.png?w=1024
# <Response [200]>
# potw1234a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/m59_0-jpg.webp?w=1024
# <Response [200]>
# ring-nebula-full_jpg-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/m60_and_ngc_4647-jpg.webp?w=1024
# <Response [200]>
# m58.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/potw1324a-jpg.webp?w=1024
# <Response [200]>
# m59_0-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/m62_0-jpg.webp?w=1024
# <Response [200]>
# m60_and_ngc_4647-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/potw1536a-jpg.webp?w=1024
# <Response [200]>
# potw1324a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/black-eye-galaxy-print-jpg.webp?w=1024
# <Response [200]>
# m62_0-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/potw1352a-1-jpg.webp?w=1024
# <Response [200]>
# potw1536a-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/heic1006a-jpg.webp?w=1024
# <Response [200]>
# black-eye-galaxy-print-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2024/03/hubble-m67-acs-1mstr-flat-final-new-tag-new.jpg?w=1024
# <Response [200]>
# potw1352a-1-jpg.png
# Descarga exitosa
# https://science.nasa.gov/wp-content/uploads/2023/04/potw1231a-jpg.webp?w=1024
# <Response [200]>
# heic1006a-jpg.png
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14480\1378359431.py in <module>
#       4     file_dir='C:/Users/Ariel/Desktop/Visual Data/Messier Img/' + save_as
#       5     download_image(image_url,save_as)
# ----> 6     download_imgdir(image_url,file_dir)
#       7     response = requests.get(image_url)
#       8     print(image_url)
#
# ~\AppData\Local\Temp\ipykernel_14480\1034366500.py in download_imgdir(image_url, file_dir)
#       1 #Definimos la función para
#       2 def download_imgdir(image_url, file_dir):
# ----> 3     response = requests.get(image_url)
#       4
#       5     if response.status_code == 200:
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     585         }
#     586         send_kwargs.update(settings)
# --> 587         resp = self.send(prep, **send_kwargs)
#     588
#     589         return resp
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     699
#     700         # Send the request
# --> 701         r = adapter.send(request, **kwargs)
#     702
#     703         # Total elapsed time of the request (approximately)
#
# C:\ProgramData\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     487         try:
#     488             if not chunked:
# --> 489                 resp = conn.urlopen(
#     490                     method=request.method,
#     491                     url=url,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# C:\ProgramData\Anaconda3\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# C:\ProgramData\Anaconda3\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# C:\ProgramData\Anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# C:\ProgramData\Anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
